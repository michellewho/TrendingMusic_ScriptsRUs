# %%
import pandas as pd

# %%
spotify_data = pd.read_csv('spotify_data.csv')
spotify_data.head(5)
# Out:
#    acousticness                                       analysis_url  \
# 0       0.44600  https://api.spotify.com/v1/audio-analysis/0NWq...
# 1       0.00155  https://api.spotify.com/v1/audio-analysis/08wJ...
# 2       0.07140  https://api.spotify.com/v1/audio-analysis/1yxg...
# 3       0.03160  https://api.spotify.com/v1/audio-analysis/0YHU...
# 4       0.27400  https://api.spotify.com/v1/audio-analysis/7r6L...
#
#    danceability  duration_ms  energy  instrumentalness  key  liveness  \
# 0         0.640       321027   0.423          0.000151    8     0.095
# 1         0.723       216800   0.824          0.167000   11     0.333
# 2         0.763       190678   0.598          0.000000   11     0.112
# 3         0.774       246240   0.739          0.000006    0     0.119
# 4         0.860       189480   0.561          0.000000    6     0.108
#
#    loudness  mode  speechiness    tempo  time_signature  valence  \
# 0   -10.567     0       0.0657  120.029             4.0    0.168
# ...

# %%
spotify_data.drop(columns=['track_href', 'type', 'uri'])

df.drop(columns=['B', 'C'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-51436834230d> in <module>()
# ----> 1 spotify_data.drop(columns=['track_href', 'type', 'uri'])
#
# TypeError: drop() got an unexpected keyword argument 'columns'
